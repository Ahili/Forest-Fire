# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/final-v11-dataset/README.dataset.txt
# /kaggle/input/final-v11-dataset/README.roboflow.txt
# /kaggle/input/final-v11-dataset/data.yaml
# /kaggle/input/final-v11-dataset/valid/labels/cl6ovzpl700cqao559u37co16_2_FALSE_COLOR_jpg.rf.0d0a46b9b33fd1502829ecfd54af50ec.txt
# /kaggle/input/final-v11-dataset/valid/labels/cl6ov6vs700brao5593c06pe7_6_SWIR_jpg.rf.c9ffa9f73aaf491cf634448667f0d0d4.txt
# /kaggle/input/final-v11-dataset/valid/labels/cl6ov2mbq00bkao55f51zgp24_6_SWIR_jpg.rf.6dc209f2f45fac378ffdc8ae708a46f1.txt
# /kaggle/input/final-v11-dataset/valid/labels/cl6ov7ksd00bsao55328v4p0c_2_FALSE_COLOR_jpg.rf.29fd543c21bfd73c291a5311bd317f2d.txt
# /kaggle/input/final-v11-dataset/valid/labels/cl6ovgpis00c3ao558rq7d0e7_4_FALSE_COLOR__URBAN_jpg.rf.9c2264476ec7dcb848d964072e24369a.txt
# /kaggle/input/final-v11-dataset/valid/labels/cl6ovmea800ccao557v4a82sn_2_FALSE_COLOR_jpg.rf.86ed011f5cda1989240cac1c26ab3f05.txt
# ...

# %%
# !pip install ultralytics --upgrade
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 18.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 7.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 28.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 74.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.9.41
#     Uninstalling nvidia-nvjitlink-cu12-12.9.41:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.9.41
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.10.19
# ...

# %%
import yaml

# Load original data.yaml
yaml_path = "/kaggle/input/final-v11-dataset/data.yaml"

with open(yaml_path, 'r') as f:
    data = yaml.safe_load(f)

# Fix the paths (use absolute paths for Kaggle)
data['train'] = '/kaggle/input/final-v11-dataset/train/images'
data['val'] = '/kaggle/input/final-v11-dataset/valid/images'
# Optional: test path if you want to evaluate
data['test'] = '/kaggle/input/final-v11-dataset/test/images'

# Save the new YAML file to working directory
new_yaml_path = '/kaggle/working/data.yaml'

with open(new_yaml_path, 'w') as f:
    yaml.dump(data, f)

print("Updated data.yaml saved at:", new_yaml_path)
# Out:
# Updated data.yaml saved at: /kaggle/working/data.yaml

# %%
import yaml

yaml_path = "/kaggle/working/data.yaml"

# Open and load the YAML file
with open(yaml_path, 'r') as f:
    data = yaml.safe_load(f)

# Print contents
print("YAML contents:")
print(data)
# Out:
# YAML contents:
# {'names': ['fire'], 'nc': 1, 'roboflow': {'license': 'CC BY 4.0', 'project': 'wildfire-yh86l', 'url': 'https://universe.roboflow.com/mini-z0ruz/wildfire-yh86l/dataset/2', 'version': 2, 'workspace': 'mini-z0ruz'}, 'test': '/kaggle/input/final-v11-dataset/test/images', 'train': '/kaggle/input/final-v11-dataset/train/images', 'val': '/kaggle/input/final-v11-dataset/valid/images'}

# %%
# !yolo task=detect mode=train data=/kaggle/working/data.yaml model="yolo11s.pt" epochs=100 imgsz=640
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.186 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO
from IPython.display import Image

# %%
from ultralytics import YOLO

# Load the trained model
# IT IS STORED IN THE FOLLOWING VALIDATION FOLDER NAMED Validating runs/detect/train/weights/best.pt.
model = YOLO('/kaggle/working/runs/detect/train2/weights/best.pt')

results = model("/kaggle/input/images-interface2/fOREST-fire/2019-09-13-00_00_2019-09-13-23_59_Sentinel-2_L2A_Wildfires.jpg")
results[0].show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_19/1660966812.py in <cell line: 0>()
#       3 # Load the trained model
#       4 # IT IS STORED IN THE FOLLOWING VALIDATION FOLDER NAMED Validating runs/detect/train/weights/best.pt.
# ----> 5 model = YOLO('/kaggle/working/runs/detect/train2/weights/best.pt')
#       6
#       7 results = model("/kaggle/input/images-interface2/fOREST-fire/2019-09-13-00_00_2019-09-13-23_59_Sentinel-2_L2A_Wildfires.jpg")
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/models/yolo/model.py in __init__(self, model, task, verbose)
#      79         else:
#      80             # Continue with default YOLO initialization
# ---> 81             super().__init__(model=model, task=task, verbose=verbose)
#      82             if hasattr(self.model, "model") and "RTDETR" in self.model.model[-1]._get_name():  # if RTDETR head
# ...

# %%
from ultralytics import YOLO

# Load the trained model
# IT IS STORED IN THE FOLLOWING VALIDATION FOLDER NAMED Validating runs/detect/train/weights/best.pt.
model = YOLO('/kaggle/working/runs/detect/train2/weights/best.pt')

results = model("/kaggle/input/images-interface2/fOREST-fire/images (1).jpg")
results[0].show()

results = model("/kaggle/input/images-interface2/fOREST-fire/images (2).jpg")
results[0].show()

results = model("/kaggle/input/images-interface2/fOREST-fire/images.jpg")
results[0].show()

# %%
import pandas as pd

# Load the results CSV
df = pd.read_csv('/kaggle/working/runs/detect/train2/results.csv')

# Display the first few rows
df.head()

# %%
# Display F1 Curve
print("F1 Curve:")
display(Image(filename='/kaggle/working/runs/detect/train2/F1_curve.png'))

# %%
# Display PR Curve
print("Precision-Recall Curve:")
display(Image(filename='/kaggle/working/runs/detect/train2/PR_curve.png'))

# %%
# Display Confusion Matrix
print("Confusion Matrix:")
display(Image(filename='/kaggle/working/runs/detect/train2/confusion_matrix.png'))

# %%
# Display Results (Metrics Over Epochs)
print("Training Results:")
display(Image(filename='/kaggle/working/runs/detect/train2/results.png'))

# %%
import time
import torch

# Example: Load YOLOv5s model
model = YOLO('/kaggle/working/runs/detect/train2/weights/best.pt')
# Replace with your test image path
img = '/kaggle/input/images-interface2/fOREST-fire/2019-09-13-00_00_2019-09-13-23_59_Sentinel-2_L2A_Wildfires.jpg'

# Measure inference time
start = time.time()
results = model(img)
end = time.time()

print(f"Latency: {(end - start)*1000:.2f} ms")

# %%
import time
import torch

# Example: Load YOLOv5s model
model = YOLO('/kaggle/working/runs/detect/train2/weights/best.pt')
# Replace with your test image path
img = '/kaggle/input/images-interface2/fOREST-fire/images (1).jpg'

# Measure inference time
start = time.time()
results = model(img)
end = time.time()

print(f"Latency: {(end - start)*1000:.2f} ms")

# %%
import time
import torch

# Example: Load YOLOv5s model
model = YOLO('/kaggle/working/runs/detect/train2/weights/best.pt')
# Replace with your test image path
img = '/kaggle/input/images-interface2/fOREST-fire/images (2).jpg'

# Measure inference time
start = time.time()
results = model(img)
end = time.time()

print(f"Latency: {(end - start)*1000:.2f} ms")

# %%
import time
import torch

# Example: Load YOLOv5s model
model = YOLO('/kaggle/working/runs/detect/train2/weights/best.pt')
# Replace with your test image path
img = '/kaggle/input/images-interface2/fOREST-fire/images.jpg'

# Measure inference time
start = time.time()
results = model(img)
end = time.time()

print(f"Latency: {(end - start)*1000:.2f} ms")
